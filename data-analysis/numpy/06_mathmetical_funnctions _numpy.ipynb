# %%
import numpy as np

# %%
arr = np.array([10,12,31,56,44])

# %%
np.mean(arr)
# Out:
# np.float64(30.6)

# %%
np.std(arr)
# Out:
# np.float64(17.861690849412884)

# %%
np.var(arr)
# Out:
# np.float64(319.04)

# %%
np.sum(arr)
# Out:
# np.int64(153)
