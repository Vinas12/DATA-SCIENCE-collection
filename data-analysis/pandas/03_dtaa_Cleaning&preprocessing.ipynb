# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\vinas\anaconda project\pandas\data_cleaning_sample.xlsx")

# %%
df
# Out:
#      Name    Age        City Geneder              Email  Join date
# 0    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 1      Bob  30.0  Lose angel       M    bob@example.com 2022-05-08
# 2  Charlie   NaN       delhi       M    cahrlie@example 2023-10-08
# 3    David  22.0      mumbai       M  david@example.com 2024-12-11
# 4      NaN  28.0       delhi       F    eve@example.com        NaT
# 5    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 6    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 7    david  22.0      mumbai       M  david@example.com 2024-12-11

# %%
df.isnull()
# Out:
#    Name     Age   City  Geneder  Email  Join date
# 0  False  False  False    False  False      False
# 1  False  False  False    False  False      False
# 2  False   True  False    False  False      False
# 3  False  False  False    False  False      False
# 4   True  False  False    False  False       True
# 5  False  False  False    False  False      False
# 6  False  False  False    False  False      False
# 7  False  False  False    False  False      False

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          1
# City         0
# Geneder      0
# Email        0
# Join date    1
# dtype: int64

# %%
df.dropna() #remove duplicate rows
# Out:
#    Name    Age        City Geneder              Email  Join date
# 0  Alice  25.0    New York       F  alice@example.com 2021-01-05
# 1    Bob  30.0  Lose angel       M    bob@example.com 2022-05-08
# 3  David  22.0      mumbai       M  david@example.com 2024-12-11
# 5  Alice  25.0    New York       F  alice@example.com 2021-01-05
# 6  Alice  25.0    New York       F  alice@example.com 2021-01-05
# 7  david  22.0      mumbai       M  david@example.com 2024-12-11

# %%
df.dropna(axis=1)
# Out:
#          City Geneder              Email
# 0    New York       F  alice@example.com
# 1  Lose angel       M    bob@example.com
# 2       delhi       M    cahrlie@example
# 3      mumbai       M  david@example.com
# 4       delhi       F    eve@example.com
# 5    New York       F  alice@example.com
# 6    New York       F  alice@example.com
# 7      mumbai       M  david@example.com

# %%
df.fillna(0)
# Out:
#      Name    Age        City Geneder              Email            Join date
# 0    Alice  25.0    New York       F  alice@example.com  2021-01-05 00:00:00
# 1      Bob  30.0  Lose angel       M    bob@example.com  2022-05-08 00:00:00
# 2  Charlie   0.0       delhi       M    cahrlie@example  2023-10-08 00:00:00
# 3    David  22.0      mumbai       M  david@example.com  2024-12-11 00:00:00
# 4        0  28.0       delhi       F    eve@example.com                    0
# 5    Alice  25.0    New York       F  alice@example.com  2021-01-05 00:00:00
# 6    Alice  25.0    New York       F  alice@example.com  2021-01-05 00:00:00
# 7    david  22.0      mumbai       M  david@example.com  2024-12-11 00:00:00

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    25.000000
# 1    30.000000
# 2    25.285714
# 3    22.000000
# 4    28.000000
# 5    25.000000
# 6    25.000000
# 7    22.000000
# Name: Age, dtype: float64

# %%
df.ffill()
# Out:
#      Name    Age        City Geneder              Email  Join date
# 0    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 1      Bob  30.0  Lose angel       M    bob@example.com 2022-05-08
# 2  Charlie  30.0       delhi       M    cahrlie@example 2023-10-08
# 3    David  22.0      mumbai       M  david@example.com 2024-12-11
# 4    David  28.0       delhi       F    eve@example.com 2024-12-11
# 5    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 6    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 7    david  22.0      mumbai       M  david@example.com 2024-12-11

# %%
df.bfill()
# Out:
#      Name    Age        City Geneder              Email  Join date
# 0    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 1      Bob  30.0  Lose angel       M    bob@example.com 2022-05-08
# 2  Charlie  22.0       delhi       M    cahrlie@example 2023-10-08
# 3    David  22.0      mumbai       M  david@example.com 2024-12-11
# 4    Alice  28.0       delhi       F    eve@example.com 2021-01-05
# 5    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 6    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 7    david  22.0      mumbai       M  david@example.com 2024-12-11

# %%
df
# Out:
#      Name    Age        City Geneder              Email  Join date
# 0    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 1      Bob  30.0  Lose angel       M    bob@example.com 2022-05-08
# 2  Charlie   NaN       delhi       M    cahrlie@example 2023-10-08
# 3    David  22.0      mumbai       M  david@example.com 2024-12-11
# 4      NaN  28.0       delhi       F    eve@example.com        NaT
# 5    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 6    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 7    david  22.0      mumbai       M  david@example.com 2024-12-11

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Name    Age        City Geneder              Email  Join date
# 0    Alice  25.0    New York       F  alice@example.com 2021-01-05
# 1      Bob  30.0  Lose angel       M    bob@example.com 2022-05-08
# 2  Charlie   NaN       delhi       M    cahrlie@example 2023-10-08
# 3    David  22.0      mumbai       M  david@example.com 2024-12-11
# 4      NaN  28.0       delhi       F    eve@example.com        NaT
# 7    david  22.0      mumbai       M  david@example.com 2024-12-11

# %%
df[' Name '].str.lower() # Converts all names to lowercase.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df["Name"].str.lower()
#
# ...

# %%
df["City"].str.contains("delhi",case=False)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# Name: City, dtype: bool

# %%
df["Email"].str.split("@")
# Out:
# 0    [alice, example.com]
# 1      [bob, example.com]
# 2      [cahrlie, example]
# 3    [david, example.com]
# 4      [eve, example.com]
# 5    [alice, example.com]
# 6    [alice, example.com]
# 7    [david, example.com]
# Name: Email, dtype: object

# %%
df2 = df.dropna().copy()               #TYOECATINF OF AGE

# %%
df2["Age"]=df["Age"].fillna(0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df2["Age"]=df["Age"].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
df2
# Out:
#    Name   Age        City Geneder              Email  Join date
# 0  Alice   25    New York       F  alice@example.com 2021-01-05
# 1    Bob   30  Lose angel       M    bob@example.com 2022-05-08
# 3  David   22      mumbai       M  david@example.com 2024-12-11
# 5  Alice   25    New York       F  alice@example.com 2021-01-05
# 6  Alice   25    New York       F  alice@example.com 2021-01-05
# 7  david   22      mumbai       M  david@example.com 2024-12-11
